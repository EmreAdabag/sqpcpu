# %%
import pickle
import numpy as np

# %%
data = pickle.load(open('stats/stockcpu_batch16_fext_stats_final.pkl', 'rb'))

# %%
data.keys()
# Out:
# dict_keys(['failed', 'cumulative_cost', 'cumulative_dist', 'best_cost', 'avg_solve_time', 'max_solve_time', 'steps', 'total_ctrl', 'total_vel'])

# %%
# print all failed in a column without 'formatting
def print_bool_list(bool_list):
    print('\n'.join(map(str, bool_list)))

print_bool_list(data['avg_solve_time'])
# Out:
# 618
# 607
# 596
# 354
# 569
# 300
# 494
# 369
# 295
# 398
# 543
# 681
# 1492
# 547
# 434
# 499
# 427
# 399
# 1341
# 831
# 479
# 173
# 308
# 562
# 631
# 480
# 341
# 550
# 638
# 555
# 652
# 591
# 320
# 585
# 723
# 615
# 507
# 439
# 432
# 660
# 586
# 494
# 525
# 689
# 1411
# 1310
# 450
# 455
# 616
# 391
# 541
# 537
# 870
# 503
# 646
# 598
# 428
# 533
# 743
# 369
# 211
# 307
# 514
# 483
# 406
# 421
# 404
# 363
# 430
# 1482
# 513
# 215
# 541
# 543
# 363
# 277
# 197
# 637
# 549
# 1593
# 565
# 588
# 435
# 331
# 1473
# 355
# 502
# 374
# 192
# 1303
# 2305
# 1379
# 206
# 341
# 610
# 591
# 287
# 1203
# 2285
# 558
# 837
# 317
# 204
# 458
# 425
# 279
# 543
# 656
# 487
# 483
# 487
# 358
# 1395
# 1202
# 240
# 440
# 898
# 199
# 473
# 353
# 565
# 492
# 613
# 1435
# 2279
# 423
# 417
# 313
# 307
# 656
# 1577
# 439
# 506
# 405
# 219
# 1309
# 1542
# 580
# 889
# 384
# 420
# 533
# 942
# 671
# 396
# 467
# 408
# 1311
# 1423
# 381
# 426
# 294
# 785
# 607
# 473
# 667
# 462
# 1431
# 978
# 535
# 389
# 1320
# ...
